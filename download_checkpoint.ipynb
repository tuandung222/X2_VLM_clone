# %% [markdown]
# #### Checkpoints
# Please make sure all parameters are loaded correctly.
# [X2VLM-base (4M)](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_4m.th)
# [X2VLM-large (4M)](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_large_4m.th)
# [X2VLM-base (1B)](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_1b.th)
# [CCLM-X2VLM-base](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/cclm_x2vlm_base.th)

# %%
# [CCLM-X2VLM-base](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/cclm_x2vlm_base.th)  

checkpoint = 'https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/cclm_x2vlm_base.th'

# download 
import requests
r = requests.get(checkpoint)
with open('cclm_x2vlm_base.th', 'wb') as f:
    f.write(r.content)

# %%
# [X2VLM-base (4M)](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_4m.th)    
def download_checkpoint(checkpoint_url, checkpoint_name):
    import requests
    r = requests.get(checkpoint_url)
    with open(checkpoint_name, 'wb') as f:
        f.write(r.content)
        
# checkpoint = 'https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_4m.th'
# download_checkpoint(checkpoint, 'x2vlm_base_4m.th')

# %%
# # x2vlm_base_1b.th
# [X2VLM-base (1B)](https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_1b.th)  

download_checkpoint('https://lf-robot-opensource.bytetos.com/obj/lab-robot-public/x2vlm_ckpts_2release/x2vlm_base_1b.th', 'x2vlm_base_1b.th')
